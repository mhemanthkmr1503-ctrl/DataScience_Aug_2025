# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mhema\OneDrive\Desktop\DataScience\MachineLearning\BivariateData.csv")

# %%
df['Hours_Studied'].cov(df['Test_Score'])
# Out:
# 27.090476190476192

# %%
df['Test_Score'].cov(df['Stress_Level'])
# Out:
# -32.53571428571428

# %%
df['Test_Score'].cov(df['Shoe_Size'])
# Out:
# -1.2238095238095237

# %% [markdown]
# - 0.7 to 1 -> Highly Correlation
# - 0.3 to 0.7 -> Medium Correlation
# - 0 to 0.3 -> Low Correlation or Zero Correlation

# %%
df['Hours_Studied'].corr(df['Test_Score'])
# Out:
# 0.9761563475950298

# %%
df['Test_Score'].corr(df['Stress_Level'])
# Out:
# -0.9802039983413029

# %%
df['Test_Score'].corr(df['Shoe_Size'])
# Out:
# -0.058575760643432236

# %%
from matplotlib import pyplot as plt

plt.scatter(df['Hours_Studied'], df['Test_Score'])

# %%
from matplotlib import pyplot as plt

plt.scatter(df['Test_Score'], df['Shoe_Size'])

# %% [markdown]
# ### Multivariate Analysis

# %%
df.corr()
# Out:
#                Hours_Studied  Test_Score  Stress_Level  Shoe_Size
# Hours_Studied       1.000000    0.976156     -0.948291  -0.175540
# Test_Score          0.976156    1.000000     -0.980204  -0.058576
# Stress_Level       -0.948291   -0.980204      1.000000   0.079436
# Shoe_Size          -0.175540   -0.058576      0.079436   1.000000

# %%
import seaborn as sns

plt.figure(figsize=(8, 6)) # Adjust figure size as needed
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 6)) # Adjust figure size as needed
sns.pairplot(df)
